# %%
import pandas as pd
import numpy as np
import csv

# %%
liked_songs['tracks/artist'].describe()
# Out:
# count          1926
# unique          268
# top       The Maine
# freq            118
# Name: tracks/artist, dtype: object

# %%
song_data=pd.read_csv("csv/allsongs.csv",low_memory=False, sep=",")

# %%
song_data = pd.read_csv("csv/allsongs.csv",dtype={'ms_played': 'int', 'spotify_episode_uri': 'str','episode_name':'str','episode_show_name':'str'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 song_data = pd.read_csv("csv/allsongs.csv",dtype={'ms_played': 'int', 'spotify_episode_uri': 'str','episode_name':'str','episode_show_name':'str'})
#       2 song_data2 = pd.read_csv("csv/allsongs.csv", dtype={ "\t"})
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers\readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers\c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\parsers.pyx:890, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\parsers.pyx:1037, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\parsers.pyx:1068, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\parsers.pyx:1187, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ValueError: Integer column has NA values in column 3

# %%
song_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166253 entries, 0 to 166252
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ts                                 166253 non-null  object
#  1   username                           28531 non-null   object
#  2   platform                           28519 non-null   object
#  3   ms_played                          28519 non-null   object
#  4   conn_country                       28504 non-null   object
#  5   ip_addr_decrypted                  28516 non-null   object
#  6   user_agent_decrypted               28327 non-null   object
#  7   master_metadata_track_name         25787 non-null   object
#  8   master_metadata_album_artist_name  25775 non-null   object
#  9   master_metadata_album_album_name   25787 non-null   object
#  10  spotify_track_uri                  25772 non-null   object
#  11  episode_name                       697 non-null     object
#  12  episode_show_name                  685 non-null     object
#  13  spotify_episode_uri                685 non-null     object
#  14  reason_start                       28503 non-null   object
#  15  reason_end                         28503 non-null   object
#  16  shuffle                            28504 non-null   object
#  17  skipped                            1347 non-null    float64
#  18  offline                            28504 non-null   object
#  19  offline_timestamp                  28504 non-null   float64
#  20  incognito_mode;;;;;                28504 non-null   object
# dtypes: float64(2), object(19)
# memory usage: 26.6+ MB

# %%
song_data.index.name = 'index'


songd_type = type(song_data)
songd_shape = song_data.shape

print(songd_type, songd_shape)
# Out:
# <class 'pandas.core.frame.DataFrame'> (166253, 20)

# %%
song_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 166253 entries, 2014-06-20T12:13:54Z to 2022-12-18T22:59:13Z,resi_maresi,"Android OS 10 API 29 (HUAWEI JNY-LX1)",49507,AT,62.240.134.80,unknown,Seventeen,Troye Sivan,Bloom,spotify:track:7iyKbBjb2fmTnTfCjCh7ER,,,,trackdone,unexpected-exit-while-paused,True,,False,1671376201078,False;;;;;
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   username                           28531 non-null  object
#  1   platform                           28519 non-null  object
#  2   ms_played                          28519 non-null  object
#  3   conn_country                       28504 non-null  object
#  4   ip_addr_decrypted                  28516 non-null  object
#  5   user_agent_decrypted               28327 non-null  object
#  6   master_metadata_track_name         25787 non-null  object
#  7   master_metadata_album_artist_name  25775 non-null  object
#  8   master_metadata_album_album_name   25787 non-null  object
#  9   spotify_track_uri                  25772 non-null  object
#  10  episode_name                       697 non-null    object
#  11  episode_show_name                  685 non-null    object
#  12  spotify_episode_uri                685 non-null    object
#  13  reason_start                       28503 non-null  object
#  14  reason_end                         28503 non-null  object
#  15  shuffle                            28504 non-null  object
#  16  skipped                            1347 non-null   float64
#  17  offline                            28504 non-null  object
#  18  offline_timestamp                  28504 non-null  float64
#  19  incognito_mode;;;;;                28504 non-null  object
# dtypes: float64(2), object(18)
# memory usage: 26.6+ MB

# %%
song_data.columns
# Out:
# Index(['username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode;;;;;'],
#       dtype='object')

# %%
song_data = song_data.rename_axis('index1').reset_index()

# %%
song_data=song_data.rename(columns={'conn_country':'country','ip_addr_decrypted':'ip_addr','master_metadata_track_name':'track','master_metadata_album_artist_name':'artist','master_metadata_album_album_name':'album','episode_show_name':'podcast_show','incognito_mode;;;;;':'incognito_mode','index1':'date_time'})

# %%
song_data.columns
# Out:
# Index(['date_time', 'username', 'platform', 'ms_played', 'country', 'ip_addr',
#        'user_agent_decrypted', 'track', 'artist', 'album', 'spotify_track_uri',
#        'episode_name', 'podcast_show', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')

# %%
song_data['date']=song_data['date_time'].str.slice(stop=11)
song_data['time']=song_data['date_time'].str.slice(start=11)

# %%
song_data.drop(['ip_addr','user_agent_decrypted','spotify_track_uri','episode_name', 'podcast_show', 'spotify_episode_uri','offline_timestamp','incognito_mode','username','date_time'],axis=1,inplace=True)

# %%
song_data.head()
# Out:
#                     platform ms_played country       track      artist album  \
# 0  Windows 8 (6.2.9200; x64)    252760      AT         One  Ed Sheeran     x
# 1  Windows 8 (6.2.9200; x64)    244573      AT  I'm a Mess  Ed Sheeran     x
# 2  Windows 8 (6.2.9200; x64)     78941      AT        Sing  Ed Sheeran     x
# 3  Windows 8 (6.2.9200; x64)     15713      AT       Don't  Ed Sheeran     x
# 4  Windows 8 (6.2.9200; x64)    225533      AT        Nina  Ed Sheeran     x
#
#   reason_start reason_end shuffle  skipped offline         date       time
# 0     clickrow  trackdone   False      0.0   False  2014-06-20T  12:13:54Z
# 1    trackdone  trackdone   False      0.0   False  2014-06-20T  12:17:58Z
# 2    trackdone   clickrow   False      1.0   False  2014-06-20T  12:19:17Z
# 3     clickrow   clickrow   False      1.0   False  2014-06-20T  12:19:34Z
# 4     clickrow  trackdone   False      0.0   False  2014-06-20T  12:23:21Z

# %%
song_data = song_data[['date', 'time','country','track','artist','album', 'ms_played','reason_start','reason_end','shuffle','skipped','offline','platform']]

# %%
song_data.head()
# Out:
#                      ts     username                   platform ms_played  \
# 0  2014-06-20T12:13:54Z  resi_maresi  Windows 8 (6.2.9200; x64)    252760
# 1  2014-06-20T12:17:58Z  resi_maresi  Windows 8 (6.2.9200; x64)    244573
# 2  2014-06-20T12:19:17Z  resi_maresi  Windows 8 (6.2.9200; x64)     78941
# 3  2014-06-20T12:19:34Z  resi_maresi  Windows 8 (6.2.9200; x64)     15713
# 4  2014-06-20T12:23:21Z  resi_maresi  Windows 8 (6.2.9200; x64)    225533
#
#   conn_country ip_addr_decrypted user_agent_decrypted  \
# 0           AT      62.46.156.68              unknown
# 1           AT      62.46.156.68              unknown
# 2           AT      62.46.156.68              unknown
# 3           AT      62.46.156.68              unknown
# 4           AT      62.46.156.68              unknown
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0                        One                        Ed Sheeran
# 1                 I'm a Mess                        Ed Sheeran
# 2                       Sing                        Ed Sheeran
# 3                      Don't                        Ed Sheeran
# 4                       Nina                        Ed Sheeran
#
#   master_metadata_album_album_name  ... episode_name episode_show_name  \
# 0                                x  ...          NaN               NaN
# 1                                x  ...          NaN               NaN
# 2                                x  ...          NaN               NaN
# 3                                x  ...          NaN               NaN
# 4                                x  ...          NaN               NaN
#
#   spotify_episode_uri reason_start reason_end shuffle skipped  offline  \
# 0                 NaN     clickrow  trackdone   False     0.0    False
# 1                 NaN    trackdone  trackdone   False     0.0    False
# 2                 NaN    trackdone   clickrow   False     1.0    False
# 3                 NaN     clickrow   clickrow   False     1.0    False
# 4                 NaN     clickrow  trackdone   False     0.0    False
#
#   offline_timestamp  incognito_mode;;;;;
# 0               0.0            False;;;;
# 1               0.0            False;;;;
# 2               0.0            False;;;;
# 3               0.0            False;;;;
# 4               0.0            False;;;;
#
# [5 rows x 21 columns]

# %%
song_data['artist'].describe()
# Out:
# count         25775
# unique         2682
# top       The Maine
# freq           1065
# Name: artist, dtype: object

# %%
song_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166253 entries, 0 to 166252
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ts                                 166253 non-null  object
#  1   username                           28531 non-null   object
#  2   platform                           28519 non-null   object
#  3   ms_played                          28519 non-null   object
#  4   conn_country                       28504 non-null   object
#  5   ip_addr_decrypted                  28516 non-null   object
#  6   user_agent_decrypted               28327 non-null   object
#  7   master_metadata_track_name         25787 non-null   object
#  8   master_metadata_album_artist_name  25775 non-null   object
#  9   master_metadata_album_album_name   25787 non-null   object
#  10  spotify_track_uri                  25772 non-null   object
#  11  episode_name                       697 non-null     object
#  12  episode_show_name                  685 non-null     object
#  13  spotify_episode_uri                685 non-null     object
#  14  reason_start                       28503 non-null   object
#  15  reason_end                         28503 non-null   object
#  16  shuffle                            28504 non-null   object
#  17  skipped                            1347 non-null    float64
#  18  offline                            28504 non-null   object
#  19  offline_timestamp                  28504 non-null   float64
#  20  incognito_mode;;;;;                28504 non-null   object
# dtypes: float64(2), object(19)
# memory usage: 26.6+ MB

# %%
song_data.tail()
# Out:
#                                                        ts username platform  \
# 166248  2022-12-18T15:04:07Z,resi_maresi,"Android OS 1...      NaN      NaN
# 166249  2022-12-18T15:04:12Z,resi_maresi,"Android OS 1...      NaN      NaN
# 166250  2022-12-18T15:06:52Z,resi_maresi,"Android OS 1...      NaN      NaN
# 166251  2022-12-18T15:10:00Z,resi_maresi,"Android OS 1...      NaN      NaN
# 166252  2022-12-18T22:59:13Z,resi_maresi,"Android OS 1...      NaN      NaN
#
#        ms_played conn_country ip_addr_decrypted user_agent_decrypted  \
# 166248       NaN          NaN               NaN                  NaN
# 166249       NaN          NaN               NaN                  NaN
# 166250       NaN          NaN               NaN                  NaN
# 166251       NaN          NaN               NaN                  NaN
# 166252       NaN          NaN               NaN                  NaN
#
#        master_metadata_track_name master_metadata_album_artist_name  \
# 166248                        NaN                               NaN
# 166249                        NaN                               NaN
# 166250                        NaN                               NaN
# 166251                        NaN                               NaN
# 166252                        NaN                               NaN
#
#        master_metadata_album_album_name  ... episode_name episode_show_name  \
# 166248                              NaN  ...          NaN               NaN
# 166249                              NaN  ...          NaN               NaN
# 166250                              NaN  ...          NaN               NaN
# 166251                              NaN  ...          NaN               NaN
# 166252                              NaN  ...          NaN               NaN
#
#        spotify_episode_uri reason_start reason_end shuffle skipped  offline  \
# 166248                 NaN          NaN        NaN     NaN     NaN      NaN
# 166249                 NaN          NaN        NaN     NaN     NaN      NaN
# 166250                 NaN          NaN        NaN     NaN     NaN      NaN
# 166251                 NaN          NaN        NaN     NaN     NaN      NaN
# 166252                 NaN          NaN        NaN     NaN     NaN      NaN
#
#        offline_timestamp  incognito_mode;;;;;
# 166248               NaN                  NaN
# 166249               NaN                  NaN
# 166250               NaN                  NaN
# 166251               NaN                  NaN
# 166252               NaN                  NaN
#
# [5 rows x 21 columns]

# %%
song_data.loc[26019]
# Out:
# ts                                   2017-09-07T10:21:31Z,resi_maresi,"Android OS 7...
# username                                                                           NaN
# platform                                                                           NaN
# ms_played                                                                          NaN
# conn_country                                                                       NaN
# ip_addr_decrypted                                                                  NaN
# user_agent_decrypted                                                               NaN
# master_metadata_track_name                                                         NaN
# master_metadata_album_artist_name                                                  NaN
# master_metadata_album_album_name                                                   NaN
# spotify_track_uri                                                                  NaN
# episode_name                                                                       NaN
# episode_show_name                                                                  NaN
# spotify_episode_uri                                                                NaN
# reason_start                                                                       NaN
# reason_end                                                                         NaN
# shuffle                                                                            NaN
# skipped                                                                            NaN
# offline                                                                            NaN
# offline_timestamp                                                                  NaN
# incognito_mode;;;;;                                                                NaN
# Name: 26019, dtype: object

# %%
liked_songs=pd.read_csv("Data/YourLibrary.csv",sep=";")

# %%
liked_songs.columns
# Out:
# Index(['tracks/artist', 'tracks/album', 'tracks/track'], dtype='object')

# %%
liked_songs=liked_songs.rename(columns={'tracks/artist':'artist','tracks/album':'album','tracks/track':'track'})

# %%
pd.set_option("display.max_rows", None)

# %%
liked_songs['artist'].value_counts()
# Out:
# The Maine                              118
# All Time Low                           109
# The Front Bottoms                       76
# Ed Sheeran                              63
# Neck Deep                               60
# The Wonder Years                        60
# Real Friends                            56
# Modern Baseball                         46
# Stand Atlantic                          45
# YUNGBLUD                                44
# State Champs                            44
